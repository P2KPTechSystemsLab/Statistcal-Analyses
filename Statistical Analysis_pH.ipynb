# %%
# ======================= Imports =======================
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# ======================= Data Setup =======================
data = {'Depth': [], 'pH': [], 'Treatment': [], 'Day': []}
depths = list(range(11))  # Depths 0 through 10

def add_treatment_data(treatment, day, depths, replicates):
    for depth_index, values in enumerate(replicates):
        for val in values:
            data['Depth'].append(depths[depth_index])
            data['pH'].append(val)
            data['Treatment'].append(treatment)
            data['Day'].append(day)
# Data for each treatment across 3 days
treatments = [
    ('Control', control_day1, control_day16, control_day64),
    ('Root Mulched', root_mulched_day1, root_mulched_day16, root_mulched_day64),
    ('Root Mixed', root_mixed_day1, root_mixed_day16, root_mixed_day64),
    ('Leaf Mulched', leaf_mulched_day1, leaf_mulched_day16, leaf_mulched_day64),
    ('Leaf Mixed', leaf_mixed_day1, leaf_mixed_day16, leaf_mixed_day64)
]

for treatment, d1, d16, d64 in treatments:
    for day, dataset in zip(['Day 1', 'Day 16', 'Day 64'], [d1, d16, d64]):
        add_treatment_data(treatment, day, depths, dataset)
df = pd.DataFrame(data)
df['Depth'] = pd.Categorical(df['Depth'], categories=depths, ordered=True)
df_filtered = df.copy()  # Use filtered copy for modeling
# ======================= Model Diagnostic Function =======================
def check_model(model, title):
    resid = model.resid
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    sns.histplot(resid, kde=True, ax=axes[0])
    axes[0].set_title(f'Residual Histogram ({title})')

    sm.qqplot(resid, line='s', ax=axes[1])
    axes[1].set_title(f'QQ Plot ({title})')
    plt.tight_layout()
    plt.show()

    # 🔴 Shapiro-Wilk test for normality
    stat, p = stats.shapiro(resid)
    print(f"{title} - Shapiro-Wilk p = {p:.4f}")
    return p
# ======================= Try Transformations =======================

# 🔴 Log Transformation
df_log = df_filtered.copy()
df_log['log_pH'] = np.log(df_log['pH'])
model_log = ols('log_pH ~ C(Treatment)*C(Depth)*C(Day)', data=df_log).fit()
check_model(model_log, 'Log Transformation')

# 🔴 Square Root Transformation
df_sqrt = df_filtered.copy()
df_sqrt['sqrt_pH'] = np.sqrt(df_sqrt['pH'])
model_sqrt = ols('sqrt_pH ~ C(Treatment)*C(Depth)*C(Day)', data=df_sqrt).fit()
check_model(model_sqrt, 'Square Root Transformation')

# 🔴 Box-Cox Transformation (automatic λ)
boxcox_values, fitted_lambda = stats.boxcox(df_filtered['pH'])
df_boxcox = df_filtered.copy()
df_boxcox['pH_boxcox'] = boxcox_values
model_boxcox = ols('pH_boxcox ~ C(Treatment)*C(Depth)*C(Day)', data=df_boxcox).fit()
check_model(model_boxcox, f'Box-Cox Transformation (λ={fitted_lambda:.3f})')

# Try λ = 0 (log) or λ = 0.5 (sqrt)
lambda_reasonable = 0.2 # square root
pH_transformed = stats.boxcox(pH_positive, lmbda=lambda_reasonable)
df_filtered['pH_boxcox_manual'] = pH_transformed

model_manual = ols('pH_boxcox_manual ~ C(Treatment)*C(Depth)*C(Day)', data=df_filtered).fit()
check_model(model_manual, f'Box-Cox Manual (λ = {lambda_reasonable:.2f})')


import numpy as np
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu
from itertools import combinations

# Constants
DEPTHS = list(range(11))
DAYS = ["Day 1", "Day 16", "Day 64"]
ALPHA = 0.05

# Organize pH data by treatment and day
TREATMENTS = {
    "Control": [control_day1, control_day16, control_day64],
    "Root Mulched": [root_mulched_day1, root_mulched_day16, root_mulched_day64],
    "Root Mixed": [root_mixed_day1, root_mixed_day16, root_mixed_day64],
    "Leaf Mulched": [leaf_mulched_day1, leaf_mulched_day16, leaf_mulched_day64],
    "Leaf Mixed": [leaf_mixed_day1, leaf_mixed_day16, leaf_mixed_day64],
}

# Helper for significance testing
def run_tests(group1, group2):
    t_stat, p_t = ttest_ind(group1, group2, equal_var=False)
    u_stat, p_u = mannwhitneyu(group1, group2, alternative='two-sided')
    return round(p_t, 4), round(p_u, 4)

# Highlight significance in styled DataFrames
def highlight_significant(val, alpha=ALPHA):
    return 'color: red' if isinstance(val, float) and val < alpha else ''

# Compare days within a treatment at each depth
def compare_over_time():
    results = []
    for treatment, days_data in TREATMENTS.items():
        for depth in DEPTHS:
            d1, d16, d64 = days_data[0][depth], days_data[1][depth], days_data[2][depth]
            for (label1, label2, data1, data2) in [
                ("Day 1", "Day 16", d1, d16),
                ("Day 1", "Day 64", d1, d64),
                ("Day 16", "Day 64", d16, d64),
            ]:
                p_t, p_u = run_tests(data1, data2)
                results.append({
                    "Treatment": treatment,
                    "Depth": depth,
                    "Compare": f"{label1} vs {label2}",
                    "Welch p": p_t,
                    "MWU p": p_u
                })
    return pd.DataFrame(results)

# Compare treatments at each depth for each day
def compare_treatments_by_depth():
    results = []
    for day_idx, day_label in enumerate(DAYS):
        for depth in DEPTHS:
            for t1, t2 in combinations(TREATMENTS.keys(), 2):
                group1 = TREATMENTS[t1][day_idx][depth]
                group2 = TREATMENTS[t2][day_idx][depth]
                p_t, p_u = run_tests(group1, group2)
                results.append({
                    "Day": day_label,
                    "Depth": depth,
                    "Compare": f"{t1} vs {t2}",
                    "Welch p": p_t,
                    "MWU p": p_u
                })
    return pd.DataFrame(results)

# Compare depths within each treatment per day
def compare_depths_within_treatment():
    results = []
    for day_idx, day_label in enumerate(DAYS):
        for treatment, day_data in TREATMENTS.items():
            depths_data = day_data[day_idx]
            for d1, d2 in combinations(DEPTHS, 2):
                p_t, p_u = run_tests(depths_data[d1], depths_data[d2])
                results.append({
                    "Day": day_label,
                    "Treatment": treatment,
                    "Compare": f"Depth {d1} vs {d2}",
                    "Welch p": p_t,
                    "MWU p": p_u
                })
    return pd.DataFrame(results)

# Display styled result
def display_styled(df, title):
    print(f"\n=== {title} ===")
    display(df.style
            .applymap(highlight_significant, subset=["Welch p", "MWU p"])
            .format({"Welch p": "{:.4f}", "MWU p": "{:.4f}"}))

# Run all comparisons
depth_time_df = compare_depths_within_treatment()
depth_treatment_df = compare_treatments_by_depth()
time_df = compare_over_time()

# Show results
display_styled(depth_time_df, "Depth Effect Across Time")
display_styled(depth_treatment_df, "Treatment Effect at Each Depth")
display_styled(time_df, "Time Effect Within Treatment by Depth")

from itertools import combinations
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd

# Constants
depths = list(range(11))  # 0 to 10 cm
days = ["Day 1", "Day 16", "Day 64"]

# Treatment data per day
treatments_by_day = {
    "Day 1": {
        "Control": control_day1,
        "Root Mulched": root_mulched_day1,
        "Root Mixed": root_mixed_day1,
        "Leaf Mulched": leaf_mulched_day1,
        "Leaf Mixed": leaf_mixed_day1,
    },
    "Day 16": {
        "Control": control_day16,
        "Root Mulched": root_mulched_day16,
        "Root Mixed": root_mixed_day16,
        "Leaf Mulched": leaf_mulched_day16,
        "Leaf Mixed": leaf_mixed_day16,
    },
    "Day 64": {
        "Control": control_day64,
        "Root Mulched": root_mulched_day64,
        "Root Mixed": root_mixed_day64,
        "Leaf Mulched": leaf_mulched_day64,
        "Leaf Mixed": leaf_mixed_day64,
    },
}

# Store test results
depth_treatment_results = []

# Compare treatments at each depth, per day
for day_label, treatments in treatments_by_day.items():
    treatment_names = list(treatments.keys())
    for depth in depths:
        for t1, t2 in combinations(treatment_names, 2):
            group1 = treatments[t1][depth]
            group2 = treatments[t2][depth]

            # Welch's t-test and Mann-Whitney U test
            t_stat, p_ttest = ttest_ind(group1, group2, equal_var=False)
            u_stat, p_mwu = mannwhitneyu(group1, group2, alternative='two-sided')

            depth_treatment_results.append({
                "Day": day_label,
                "Depth": depth,
                "Compare": f"{t1} vs {t2}",
                "Welch p": round(p_ttest, 4),
                "MWU p": round(p_mwu, 4)
            })

# Convert to DataFrame
depth_treatment_df = pd.DataFrame(depth_treatment_results)

# Style helper
def highlight_significant(val, alpha=0.05):
    if isinstance(val, float) and val < alpha:
        return 'color: red'
    return ''

# Display styled table
print("=== Depth Effect Across Treatments ===")
display(
    depth_treatment_df.style
        .applymap(highlight_significant, subset=["Welch p", "MWU p"])
        .format({"Welch p": "{:.4f}", "MWU p": "{:.4f}"})
)

from itertools import combinations
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd

# Constants
depths = list(range(11))  # 0 to 10 cm
days = ["Day 1", "Day 16", "Day 64"]

# Organize treatment data by day
treatments_by_day = {
    "Day 1": {
        "Control": control_day1,
        "Root Mulched": root_mulched_day1,
        "Root Mixed": root_mixed_day1,
        "Leaf Mulched": leaf_mulched_day1,
        "Leaf Mixed": leaf_mixed_day1,
    },
    "Day 16": {
        "Control": control_day16,
        "Root Mulched": root_mulched_day16,
        "Root Mixed": root_mixed_day16,
        "Leaf Mulched": leaf_mulched_day16,
        "Leaf Mixed": leaf_mixed_day16,
    },
    "Day 64": {
        "Control": control_day64,
        "Root Mulched": root_mulched_day64,
        "Root Mixed": root_mixed_day64,
        "Leaf Mulched": leaf_mulched_day64,
        "Leaf Mixed": leaf_mixed_day64,
    },
}

# Store results
depth_time_results = []

# Compare depths over time within each treatment
for treatment in treatments_by_day["Day 1"].keys():  # All treatments assumed same across days
    for depth in depths:
        # Get same-depth data across days
        d1 = treatments_by_day["Day 1"][treatment][depth]
        d16 = treatments_by_day["Day 16"][treatment][depth]
        d64 = treatments_by_day["Day 64"][treatment][depth]

        for (label_a, label_b, arr_a, arr_b) in [
            ("Day 1", "Day 16", d1, d16),
            ("Day 1", "Day 64", d1, d64),
            ("Day 16", "Day 64", d16, d64)
        ]:
            # Welch's t-test and Mann-Whitney U test
            t_stat, p_ttest = ttest_ind(arr_a, arr_b, equal_var=False)
            u_stat, p_mwu = mannwhitneyu(arr_a, arr_b, alternative='two-sided')

            depth_time_results.append({
                "Treatment": treatment,
                "Depth": depth,
                "Compare": f"{label_a} vs {label_b}",
                "Welch p": round(p_ttest, 4),
                "MWU p": round(p_mwu, 4)
            })

# Create DataFrame
depth_time_df = pd.DataFrame(depth_time_results)

# Style helper
def highlight_significant(val, alpha=0.05):
    if isinstance(val, float) and val < alpha:
        return 'color: red'
    return ''

# Display styled table
print("=== Depth Effect Across Time ===")
display(
    depth_time_df.style
        .applymap(highlight_significant, subset=["Welch p", "MWU p"])
        .format({"Welch p": "{:.4f}", "MWU p": "{:.4f}"})
)


from itertools import combinations
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd

# Constants
depths = list(range(11))  # 0 to 10 cm
days = ["Day 1", "Day 16", "Day 64"]
treatment_labels = ["Control", "Root Mulched", "Root Mixed", "Leaf Mulched", "Leaf Mixed"]

# Organize all data by day
all_data_by_day = {
    "Day 1": {
        "Control": control_day1,
        "Root Mulched": root_mulched_day1,
        "Root Mixed": root_mixed_day1,
        "Leaf Mulched": leaf_mulched_day1,
        "Leaf Mixed": leaf_mulched_day1,
    },
    "Day 16": {
        "Control": control_day16,
        "Root Mulched": root_mulched_day16,
        "Root Mixed": root_mixed_day16,
        "Leaf Mulched": leaf_mulched_day16,
        "Leaf Mixed": leaf_mulched_day16,
    },
    "Day 64": {
        "Control": control_day64,
        "Root Mulched": root_mulched_day64,
        "Root Mixed": root_mixed_day64,
        "Leaf Mulched": leaf_mulched_day64,
        "Leaf Mixed": leaf_mixed_day64,
    },
}

# Store results
interaction_results = []

# Compare treatment combinations at each depth for each day
for day in days:
    treatments = all_data_by_day[day]
    
    for depth in depths:
        for (treat_a, treat_b) in combinations(treatments.keys(), 2):
            arr_a = treatments[treat_a][depth]
            arr_b = treatments[treat_b][depth]

            # Welch's t-test and Mann-Whitney U
            t_stat, p_ttest = ttest_ind(arr_a, arr_b, equal_var=False)
            u_stat, p_mwu = mannwhitneyu(arr_a, arr_b, alternative='two-sided')

            interaction_results.append({
                "Day": day,
                "Depth": depth,
                "Compare": f"{treat_a} vs {treat_b}",
                "Welch p": round(p_ttest, 4),
                "MWU p": round(p_mwu, 4)
            })

# Convert to DataFrame
interaction_df = pd.DataFrame(interaction_results)

# Styling
def highlight_significant(val, alpha=0.05):
    if isinstance(val, float) and val < alpha:
        return 'color: red'
    return ''

# Display
print("=== Depth × Treatment × Time Interaction ===")
display(
    interaction_df.style
        .applymap(highlight_significant, subset=["Welch p", "MWU p"])
        .format({"Welch p": "{:.4f}", "MWU p": "{:.4f}"})
)



# ---  Visualization ---
plt.figure(figsize=(14, 6))
sns.boxplot(data=df_filtered, x="Day", y="pH", hue="Treatment")
plt.title("pH Distribution Across Treatments and Days")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Log Transformation - Shapiro-Wilk p = 0.0000
# Square Root Transformation - Shapiro-Wilk p = 0.0000
# Box-Cox Transformation (λ=11.055) - Shapiro-Wilk p = 0.0000
# Box-Cox Manual (λ = 0.20) - Shapiro-Wilk p = 0.0000
# C:\Users\Kenneth\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# === Depth Effect Across Time ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:171: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_ee9fe_row111_col3, #T_ee9fe_row112_col3, #T_ee9fe_row113_col3, #T_ee9fe_row114_col3, #T_ee9fe_row117_col3, #T_ee9fe_row118_col3, #T_ee9fe_row332_col3, #T_ee9fe_row332_col4, #T_ee9fe_row333_col3, #T_ee9fe_row333_col4, #T_ee9fe_row334_col3, #T_ee9fe_row334_col4, #T_ee9fe_row335_col3, #T_ee9fe_row335_col4, #T_ee9fe_row336_col3, #T_ee9fe_row336_col4, #T_ee9fe_row337_col3, #T_ee9fe_row337_col4, #T_ee9fe_row338_col3, #T_ee9fe_row338_col4, #T_ee9fe_row339_col3, #T_ee9fe_row339_col4, #T_ee9fe_row341_col3, #T_ee9fe_row341_col4, #T_ee9fe_row342_col3, #T_ee9fe_row342_col4, #T_ee9fe_row343_col3, #T_ee9fe_row343_col4, #T_ee9fe_row344_col3, #T_ee9fe_row344_col4, #T_ee9fe_row345_col3, #T_ee9fe_row345_col4, #T_ee9fe_row346_col3, #T_ee9fe_row346_col4, #T_ee9fe_row347_col3, #T_ee9fe_row347_col4, #T_ee9fe_row348_col3, #T_ee9fe_row348_col4, #T_ee9fe_row349_col3, #T_ee9fe_row349_col4, #T_ee9fe_row350_col3, #T_ee9fe_row350_col4, #T_ee9fe_row351_col3, #T_ee9fe_row351_col4, #T_ee9fe_row352_col3, #T_ee9fe_row352_col4, #T_ee9fe_row353_col3, #T_ee9fe_row353_col4, #T_ee9fe_row354_col3, #T_ee9fe_row354_col4, #T_ee9fe_row355_col3, #T_ee9fe_row355_col4, #T_ee9fe_row356_col3, #T_ee9fe_row356_col4, #T_ee9fe_row357_col3, #T_ee9fe_row357_col4, #T_ee9fe_row358_col3, #T_ee9fe_row358_col4, #T_ee9fe_row359_col3, #T_ee9fe_row359_col4, #T_ee9fe_row360_col3, #T_ee9fe_row360_col4, #T_ee9fe_row361_col3, #T_ee9fe_row361_col4, #T_ee9fe_row362_col3, #T_ee9fe_row362_col4, #T_ee9fe_row363_col3, #T_ee9fe_row363_col4, #T_ee9fe_row387_col3, #T_ee9fe_row387_col4, #T_ee9fe_row388_col3, #T_ee9fe_row388_col4, #T_ee9fe_row389_col3, #T_ee9fe_row389_col4, #T_ee9fe_row390_col3, #T_ee9fe_row390_col4, #T_ee9fe_row391_col3, #T_ee9fe_row391_col4, #T_ee9fe_row392_col3, #T_ee9fe_row392_col4, #T_ee9fe_row393_col3, #T_ee9fe_row393_col4, #T_ee9fe_row394_col3, #T_ee9fe_row394_col4, #T_ee9fe_row396_col3, #T_ee9fe_row396_col4, #T_ee9fe_row397_col3, #T_ee9fe_row397_col4, #T_ee9fe_row398_col3, #T_ee9fe_row398_col4, #T_ee9fe_row399_col3, #T_ee9fe_row399_col4, #T_ee9fe_row400_col3, #T_ee9fe_row400_col4, #T_ee9fe_row401_col3, #T_ee9fe_row401_col4, #T_ee9fe_row402_col3, #T_ee9fe_row402_col4, #T_ee9fe_row403_col3, #T_ee9fe_row403_col4, #T_ee9fe_row404_col3, #T_ee9fe_row404_col4, #T_ee9fe_row405_col3, #T_ee9fe_row405_col4, #T_ee9fe_row406_col3, #T_ee9fe_row406_col4, #T_ee9fe_row407_col3, #T_ee9fe_row407_col4, #T_ee9fe_row408_col3, #T_ee9fe_row408_col4, #T_ee9fe_row409_col3, #T_ee9fe_row409_col4, #T_ee9fe_row410_col3, #T_ee9fe_row410_col4, #T_ee9fe_row411_col3, #T_ee9fe_row411_col4, #T_ee9fe_row412_col3, #T_ee9fe_row412_col4, #T_ee9fe_row413_col3, #T_ee9fe_row413_col4, #T_ee9fe_row414_col3, #T_ee9fe_row414_col4, #T_ee9fe_row415_col3, #T_ee9fe_row415_col4, #T_ee9fe_row416_col3, #T_ee9fe_row416_col4, #T_ee9fe_row417_col3, #T_ee9fe_row417_col4, #T_ee9fe_row418_col3, #T_ee9fe_row418_col4, #T_ee9fe_row420_col3, #T_ee9fe_row420_col4, #T_ee9fe_row421_col3, #T_ee9fe_row421_col4, #T_ee9fe_row422_col3, #T_ee9fe_row422_col4, #T_ee9fe_row423_col3, #T_ee9fe_row423_col4, #T_ee9fe_row424_col3, #T_ee9fe_row424_col4, #T_ee9fe_row425_col3, #T_ee9fe_row425_col4, #T_ee9fe_row426_col3, #T_ee9fe_row426_col4, #T_ee9fe_row427_col3, #T_ee9fe_row427_col4, #T_ee9fe_row428_col3, #T_ee9fe_row428_col4, #T_ee9fe_row429_col3, #T_ee9fe_row429_col4, #T_ee9fe_row442_col3, #T_ee9fe_row442_col4, #T_ee9fe_row443_col3, #T_ee9fe_row443_col4, #T_ee9fe_row444_col3, #T_ee9fe_row444_col4, #T_ee9fe_row445_col3, #T_ee9fe_row445_col4, #T_ee9fe_row446_col3, #T_ee9fe_row446_col4, #T_ee9fe_row447_col3, #T_ee9fe_row447_col4, #T_ee9fe_row448_col3, #T_ee9fe_row448_col4, #T_ee9fe_row449_col3, #T_ee9fe_row449_col4, #T_ee9fe_row451_col3, #T_ee9fe_row451_col4, #T_ee9fe_row452_col3, #T_ee9fe_row452_col4, #T_ee9fe_row453_col3, #T_ee9fe_row453_col4, #T_ee9fe_row454_col3, #T_ee9fe_row454_col4, #T_ee9fe_row455_col3, #T_ee9fe_row455_col4, #T_ee9fe_row456_col3, #T_ee9fe_row456_col4, #T_ee9fe_row457_col3, #T_ee9fe_row457_col4, #T_ee9fe_row458_col3, #T_ee9fe_row458_co ...
# === Treatment Effect at Each Depth ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:171: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_390c8_row7_col3, #T_390c8_row110_col3, #T_390c8_row110_col4, #T_390c8_row111_col3, #T_390c8_row111_col4, #T_390c8_row112_col3, #T_390c8_row112_col4, #T_390c8_row113_col3, #T_390c8_row113_col4, #T_390c8_row114_col3, #T_390c8_row114_col4, #T_390c8_row115_col3, #T_390c8_row115_col4, #T_390c8_row116_col3, #T_390c8_row116_col4, #T_390c8_row117_col3, #T_390c8_row117_col4, #T_390c8_row118_col3, #T_390c8_row118_col4, #T_390c8_row119_col3, #T_390c8_row119_col4, #T_390c8_row120_col3, #T_390c8_row120_col4, #T_390c8_row121_col3, #T_390c8_row121_col4, #T_390c8_row122_col3, #T_390c8_row122_col4, #T_390c8_row123_col3, #T_390c8_row123_col4, #T_390c8_row124_col3, #T_390c8_row124_col4, #T_390c8_row125_col3, #T_390c8_row125_col4, #T_390c8_row126_col3, #T_390c8_row126_col4, #T_390c8_row127_col3, #T_390c8_row127_col4, #T_390c8_row128_col3, #T_390c8_row128_col4, #T_390c8_row129_col3, #T_390c8_row129_col4, #T_390c8_row130_col3, #T_390c8_row130_col4, #T_390c8_row131_col3, #T_390c8_row131_col4, #T_390c8_row132_col3, #T_390c8_row132_col4, #T_390c8_row133_col3, #T_390c8_row133_col4, #T_390c8_row134_col3, #T_390c8_row134_col4, #T_390c8_row135_col3, #T_390c8_row135_col4, #T_390c8_row136_col3, #T_390c8_row136_col4, #T_390c8_row137_col3, #T_390c8_row137_col4, #T_390c8_row138_col3, #T_390c8_row138_col4, #T_390c8_row139_col3, #T_390c8_row139_col4, #T_390c8_row140_col3, #T_390c8_row140_col4, #T_390c8_row141_col3, #T_390c8_row141_col4, #T_390c8_row142_col3, #T_390c8_row142_col4, #T_390c8_row143_col3, #T_390c8_row143_col4, #T_390c8_row144_col3, #T_390c8_row144_col4, #T_390c8_row145_col3, #T_390c8_row145_col4, #T_390c8_row146_col3, #T_390c8_row146_col4, #T_390c8_row147_col3, #T_390c8_row147_col4, #T_390c8_row148_col3, #T_390c8_row148_col4, #T_390c8_row149_col3, #T_390c8_row149_col4, #T_390c8_row151_col3, #T_390c8_row151_col4, #T_390c8_row152_col3, #T_390c8_row152_col4, #T_390c8_row153_col3, #T_390c8_row153_col4, #T_390c8_row154_col3, #T_390c8_row154_col4, #T_390c8_row155_col3, #T_390c8_row155_col4, #T_390c8_row156_col3, #T_390c8_row156_col4, #T_390c8_row158_col3, #T_390c8_row158_col4, #T_390c8_row159_col3, #T_390c8_row159_col4, #T_390c8_row161_col3, #T_390c8_row161_col4, #T_390c8_row162_col3, #T_390c8_row162_col4, #T_390c8_row163_col3, #T_390c8_row163_col4, #T_390c8_row164_col3, #T_390c8_row164_col4, #T_390c8_row165_col3, #T_390c8_row165_col4, #T_390c8_row166_col3, #T_390c8_row166_col4, #T_390c8_row167_col3, #T_390c8_row167_col4, #T_390c8_row168_col3, #T_390c8_row168_col4, #T_390c8_row169_col3, #T_390c8_row169_col4, #T_390c8_row171_col3, #T_390c8_row173_col3, #T_390c8_row173_col4, #T_390c8_row174_col3, #T_390c8_row176_col3, #T_390c8_row176_col4, #T_390c8_row177_col3, #T_390c8_row178_col3, #T_390c8_row178_col4, #T_390c8_row179_col3, #T_390c8_row179_col4, #T_390c8_row181_col3, #T_390c8_row184_col3, #T_390c8_row187_col3, #T_390c8_row191_col3, #T_390c8_row191_col4, #T_390c8_row192_col3, #T_390c8_row193_col3, #T_390c8_row194_col3, #T_390c8_row194_col4, #T_390c8_row195_col3, #T_390c8_row195_col4, #T_390c8_row196_col3, #T_390c8_row196_col4, #T_390c8_row201_col3, #T_390c8_row202_col3, #T_390c8_row202_col4, #T_390c8_row205_col3, #T_390c8_row211_col3, #T_390c8_row211_col4, #T_390c8_row212_col3, #T_390c8_row212_col4, #T_390c8_row213_col3, #T_390c8_row213_col4, #T_390c8_row220_col3, #T_390c8_row220_col4, #T_390c8_row221_col3, #T_390c8_row221_col4, #T_390c8_row222_col3, #T_390c8_row222_col4, #T_390c8_row223_col3, #T_390c8_row223_col4, #T_390c8_row224_col3, #T_390c8_row224_col4, #T_390c8_row225_col3, #T_390c8_row225_col4, #T_390c8_row226_col3, #T_390c8_row226_col4, #T_390c8_row228_col3, #T_390c8_row228_col4, #T_390c8_row229_col3, #T_390c8_row229_col4, #T_390c8_row230_col3, #T_390c8_row230_col4, #T_390c8_row231_col3, #T_390c8_row231_col4, #T_390c8_row232_col3, #T_390c8_row232_col4, #T_390c8_row233_col3, #T_390c8_row233_col4, #T_390c8_row234_col3, #T_390c8_row234_col4, #T_390c8_row236_col3, #T_390c8_row236_col4, #T_390c8_row237_col3, #T_390c8_row237_col4, #T_390c8_row238_col3 ...
#   color: red;
# }
# </style>
# <table id="T_390c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_390c8_level0_col0" class="col_heading level0 col0" >Day</th>
#       <th id="T_390c8_level0_col1" class="col_heading level0 col1" >Depth</th>
#       <th id="T_390c8_level0_col2" class="col_heading level0 col2" >Compare</th>
#       <th id="T_390c8_level0_col3" class="col_heading level0 col3" >Welch p</th>
#       <th id="T_390c8_level0_col4" class="col_heading level0 col4" >MWU p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_390c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_390c8_row0_col0" class="data row0 col0" >Day 1</td>
#       <td id="T_390c8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_390c8_row0_col2" class="data row0 col2" >Control vs Root Mulched</td>
#       <td id="T_390c8_row0_col3" class="data row0 col3" >0.4881</td>
#       <td id="T_390c8_row0_col4" class="data row0 col4" >0.5412</td>
#     </tr>
#     <tr>
#       <th id="T_390c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_390c8_row1_col0" class="data row1 col0" >Day 1</td>
#       <td id="T_390c8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_390c8_row1_col2" class="data row1 col2" >Control vs Root Mixed</td>
#       <td id="T_390c8_row1_col3" class="data row1 col3" >0.6737</td>
#       <td id="T_390c8_row1_col4" class="data row1 col4" >0.8744</td>
#     </tr>
#     <tr>
#       <th id="T_390c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_390c8_row2_col0" class="data row2 col0" >Day 1</td>
#       <td id="T_390c8_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_390c8_row2_col2" class="data row2 col2" >Control vs Leaf Mulched</td>
#       <td id="T_390c8_row2_col3" class="data row2 col3" >0.2382</td>
#       <td id="T_390c8_row2_col4" class="data row2 col4" >0.2849</td>
#     </tr>
#     <tr>
#       <th id="T_390c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_390c8_row3_col0" class="data row3 col0" >Day 1</td>
#       <td id="T_390c8_row3_col1" class="data
# === Time Effect Within Treatment by Depth ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:171: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_5a5fe_row0_col3, #T_5a5fe_row0_col4, #T_5a5fe_row1_col3, #T_5a5fe_row1_col4, #T_5a5fe_row3_col3, #T_5a5fe_row3_col4, #T_5a5fe_row4_col3, #T_5a5fe_row4_col4, #T_5a5fe_row6_col3, #T_5a5fe_row6_col4, #T_5a5fe_row7_col3, #T_5a5fe_row7_col4, #T_5a5fe_row9_col3, #T_5a5fe_row9_col4, #T_5a5fe_row10_col3, #T_5a5fe_row10_col4, #T_5a5fe_row12_col3, #T_5a5fe_row12_col4, #T_5a5fe_row15_col3, #T_5a5fe_row15_col4, #T_5a5fe_row16_col3, #T_5a5fe_row16_col4, #T_5a5fe_row18_col3, #T_5a5fe_row18_col4, #T_5a5fe_row19_col3, #T_5a5fe_row19_col4, #T_5a5fe_row21_col3, #T_5a5fe_row21_col4, #T_5a5fe_row24_col3, #T_5a5fe_row24_col4, #T_5a5fe_row27_col3, #T_5a5fe_row27_col4, #T_5a5fe_row28_col3, #T_5a5fe_row28_col4, #T_5a5fe_row30_col3, #T_5a5fe_row30_col4, #T_5a5fe_row31_col3, #T_5a5fe_row32_col3, #T_5a5fe_row32_col4, #T_5a5fe_row33_col3, #T_5a5fe_row33_col4, #T_5a5fe_row34_col3, #T_5a5fe_row34_col4, #T_5a5fe_row35_col3, #T_5a5fe_row35_col4, #T_5a5fe_row36_col3, #T_5a5fe_row36_col4, #T_5a5fe_row37_col3, #T_5a5fe_row37_col4, #T_5a5fe_row38_col3, #T_5a5fe_row38_col4, #T_5a5fe_row39_col3, #T_5a5fe_row39_col4, #T_5a5fe_row40_col3, #T_5a5fe_row40_col4, #T_5a5fe_row41_col3, #T_5a5fe_row41_col4, #T_5a5fe_row42_col3, #T_5a5fe_row42_col4, #T_5a5fe_row43_col3, #T_5a5fe_row43_col4, #T_5a5fe_row45_col3, #T_5a5fe_row45_col4, #T_5a5fe_row46_col3, #T_5a5fe_row46_col4, #T_5a5fe_row47_col3, #T_5a5fe_row47_col4, #T_5a5fe_row48_col3, #T_5a5fe_row48_col4, #T_5a5fe_row50_col3, #T_5a5fe_row50_col4, #T_5a5fe_row51_col3, #T_5a5fe_row51_col4, #T_5a5fe_row53_col3, #T_5a5fe_row53_col4, #T_5a5fe_row54_col3, #T_5a5fe_row54_col4, #T_5a5fe_row56_col3, #T_5a5fe_row56_col4, #T_5a5fe_row57_col3, #T_5a5fe_row57_col4, #T_5a5fe_row59_col3, #T_5a5fe_row59_col4, #T_5a5fe_row60_col3, #T_5a5fe_row60_col4, #T_5a5fe_row63_col3, #T_5a5fe_row63_col4, #T_5a5fe_row64_col3, #T_5a5fe_row64_col4, #T_5a5fe_row66_col3, #T_5a5fe_row66_col4, #T_5a5fe_row67_col3, #T_5a5fe_row67_col4, #T_5a5fe_row68_col3, #T_5a5fe_row68_col4, #T_5a5fe_row69_col3, #T_5a5fe_row69_col4, #T_5a5fe_row70_col3, #T_5a5fe_row70_col4, #T_5a5fe_row71_col3, #T_5a5fe_row71_col4, #T_5a5fe_row72_col3, #T_5a5fe_row72_col4, #T_5a5fe_row73_col3, #T_5a5fe_row73_col4, #T_5a5fe_row75_col3, #T_5a5fe_row75_col4, #T_5a5fe_row76_col3, #T_5a5fe_row76_col4, #T_5a5fe_row77_col3, #T_5a5fe_row77_col4, #T_5a5fe_row78_col3, #T_5a5fe_row78_col4, #T_5a5fe_row79_col3, #T_5a5fe_row79_col4, #T_5a5fe_row80_col3, #T_5a5fe_row80_col4, #T_5a5fe_row81_col3, #T_5a5fe_row81_col4, #T_5a5fe_row82_col3, #T_5a5fe_row83_col3, #T_5a5fe_row83_col4, #T_5a5fe_row90_col3, #T_5a5fe_row90_col4, #T_5a5fe_row91_col3, #T_5a5fe_row91_col4, #T_5a5fe_row93_col3, #T_5a5fe_row94_col3, #T_5a5fe_row99_col3, #T_5a5fe_row99_col4, #T_5a5fe_row100_col3, #T_5a5fe_row100_col4, #T_5a5fe_row101_col3, #T_5a5fe_row101_col4, #T_5a5fe_row102_col3, #T_5a5fe_row102_col4, #T_5a5fe_row103_col3, #T_5a5fe_row103_col4, #T_5a5fe_row104_col3, #T_5a5fe_row104_col4, #T_5a5fe_row105_col3, #T_5a5fe_row105_col4, #T_5a5fe_row106_col3, #T_5a5fe_row106_col4, #T_5a5fe_row107_col3, #T_5a5fe_row107_col4, #T_5a5fe_row108_col3, #T_5a5fe_row108_col4, #T_5a5fe_row109_col3, #T_5a5fe_row109_col4, #T_5a5fe_row110_col3, #T_5a5fe_row110_col4, #T_5a5fe_row111_col3, #T_5a5fe_row111_col4, #T_5a5fe_row112_col3, #T_5a5fe_row112_col4, #T_5a5fe_row113_col3, #T_5a5fe_row113_col4, #T_5a5fe_row114_col3, #T_5a5fe_row114_col4, #T_5a5fe_row115_col3, #T_5a5fe_row115_col4, #T_5a5fe_row116_col3, #T_5a5fe_row116_col4, #T_5a5fe_row117_col3, #T_5a5fe_row117_col4, #T_5a5fe_row118_col3, #T_5a5fe_row118_col4, #T_5a5fe_row120_col3, #T_5a5fe_row120_col4, #T_5a5fe_row122_col3, #T_5a5fe_row122_col4, #T_5a5fe_row123_col3, #T_5a5fe_row123_col4, #T_5a5fe_row124_col3, #T_5a5fe_row130_col3, #T_5a5fe_row132_col3, #T_5a5fe_row132_col4, #T_5a5fe_row133_col3, #T_5a5fe_row133_col4, #T_5a5fe_row134_col3, #T_5a5fe_row134_col4, #T_5a5fe_row135_col3, #T_5a5fe_row135_col4, #T_5a5fe_row136_col3, #T_5a5fe_row136_col4, #T_5a5fe_row137_col3, #T_5a5fe_row137_col4, #T_5a5fe ...
#   color: red;
# }
# </style>
# <table id="T_5a5fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a5fe_level0_col0" class="col_heading level0 col0" >Treatment</th>
#       <th id="T_5a5fe_level0_col1" class="col_heading level0 col1" >Depth</th>
#       <th id="T_5a5fe_level0_col2" class="col_heading level0 col2" >Compare</th>
#       <th id="T_5a5fe_level0_col3" class="col_heading level0 col3" >Welch p</th>
#       <th id="T_5a5fe_level0_col4" class="col_heading level0 col4" >MWU p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a5fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a5fe_row0_col0" class="data row0 col0" >Control</td>
#       <td id="T_5a5fe_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5a5fe_row0_col2" class="data row0 col2" >Day 1 vs Day 16</td>
#       <td id="T_5a5fe_row0_col3" class="data row0 col3" >0.0167</td>
#       <td id="T_5a5fe_row0_col4" class="data row0 col4" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_5a5fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a5fe_row1_col0" class="data row1 col0" >Control</td>
#       <td id="T_5a5fe_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5a5fe_row1_col2" class="data row1 col2" >Day 1 vs Day 64</td>
#       <td id="T_5a5fe_row1_col3" class="data row1 col3" >0.0193</td>
#       <td id="T_5a5fe_row1_col4" class="data row1 col4" >0.0485</td>
#     </tr>
#     <tr>
#       <th id="T_5a5fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a5fe_row2_col0" class="data row2 col0" >Control</td>
#       <td id="T_5a5fe_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_5a5fe_row2_col2" class="data row2 col2" >Day 16 vs Day 64</td>
#       <td id="T_5a5fe_row2_col3" class="data row2 col3" >0.2805</td>
#       <td id="T_5a5fe_row2_col4" class="data row2 col4" >0.2881</td>
#     </tr>
#     <tr>
#       <th id="T_5a5fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a5fe_row3_col0" class="data row3 col0" >Control</td>
#       <td id="T_5a5fe_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_5a5fe_row3_col2" class="data row3 col2" >Day 1 vs Day 16</td>
#       <td id="T_5a5fe_row3_col3" class="data row3 col3" >0.0004</td>
#       <td id="T_5a5fe_row3_col4" class="data row3 col4" >0.0247</td>
#     </tr>
#     <tr>
#       <th id="T_5a5fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a5fe_row4_col0" class="data row4 col0" >Control</td>
#       <td id="T_5a5fe_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_5a5fe_row4_col2" class="data row4 col2" >Day 1 vs Day 64</td>
#       <td id="T_5a5fe_row4_col3" class="data row4 col3" >0.0217</td>
#       <td id="T_5a5fe_row4_col4" class="data row4 col4" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_5a5fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a5fe_row5_col0" class="data row5 col0" >Control</td>
#       <td id="T_5a5fe_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_5a5fe_row5_col2" class="data row5 col2" >Day 16 vs Day 64</td>
#       <td id="T_5a5fe_row5_col3" class="data row5 col3" >0.7354</td>
#       <td id="T_5a5fe_row5_col4" class="data row5 col4" >0.64
# C:\Users\Kenneth\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# === Depth Effect Across Treatments ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:253: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_cd43c_row7_col3, #T_cd43c_row110_col3, #T_cd43c_row110_col4, #T_cd43c_row111_col3, #T_cd43c_row111_col4, #T_cd43c_row112_col3, #T_cd43c_row112_col4, #T_cd43c_row113_col3, #T_cd43c_row113_col4, #T_cd43c_row114_col3, #T_cd43c_row114_col4, #T_cd43c_row115_col3, #T_cd43c_row115_col4, #T_cd43c_row116_col3, #T_cd43c_row116_col4, #T_cd43c_row117_col3, #T_cd43c_row117_col4, #T_cd43c_row118_col3, #T_cd43c_row118_col4, #T_cd43c_row119_col3, #T_cd43c_row119_col4, #T_cd43c_row120_col3, #T_cd43c_row120_col4, #T_cd43c_row121_col3, #T_cd43c_row121_col4, #T_cd43c_row122_col3, #T_cd43c_row122_col4, #T_cd43c_row123_col3, #T_cd43c_row123_col4, #T_cd43c_row124_col3, #T_cd43c_row124_col4, #T_cd43c_row125_col3, #T_cd43c_row125_col4, #T_cd43c_row126_col3, #T_cd43c_row126_col4, #T_cd43c_row127_col3, #T_cd43c_row127_col4, #T_cd43c_row128_col3, #T_cd43c_row128_col4, #T_cd43c_row129_col3, #T_cd43c_row129_col4, #T_cd43c_row130_col3, #T_cd43c_row130_col4, #T_cd43c_row131_col3, #T_cd43c_row131_col4, #T_cd43c_row132_col3, #T_cd43c_row132_col4, #T_cd43c_row133_col3, #T_cd43c_row133_col4, #T_cd43c_row134_col3, #T_cd43c_row134_col4, #T_cd43c_row135_col3, #T_cd43c_row135_col4, #T_cd43c_row136_col3, #T_cd43c_row136_col4, #T_cd43c_row137_col3, #T_cd43c_row137_col4, #T_cd43c_row138_col3, #T_cd43c_row138_col4, #T_cd43c_row139_col3, #T_cd43c_row139_col4, #T_cd43c_row140_col3, #T_cd43c_row140_col4, #T_cd43c_row141_col3, #T_cd43c_row141_col4, #T_cd43c_row142_col3, #T_cd43c_row142_col4, #T_cd43c_row143_col3, #T_cd43c_row143_col4, #T_cd43c_row144_col3, #T_cd43c_row144_col4, #T_cd43c_row145_col3, #T_cd43c_row145_col4, #T_cd43c_row146_col3, #T_cd43c_row146_col4, #T_cd43c_row147_col3, #T_cd43c_row147_col4, #T_cd43c_row148_col3, #T_cd43c_row148_col4, #T_cd43c_row149_col3, #T_cd43c_row149_col4, #T_cd43c_row151_col3, #T_cd43c_row151_col4, #T_cd43c_row152_col3, #T_cd43c_row152_col4, #T_cd43c_row153_col3, #T_cd43c_row153_col4, #T_cd43c_row154_col3, #T_cd43c_row154_col4, #T_cd43c_row155_col3, #T_cd43c_row155_col4, #T_cd43c_row156_col3, #T_cd43c_row156_col4, #T_cd43c_row158_col3, #T_cd43c_row158_col4, #T_cd43c_row159_col3, #T_cd43c_row159_col4, #T_cd43c_row161_col3, #T_cd43c_row161_col4, #T_cd43c_row162_col3, #T_cd43c_row162_col4, #T_cd43c_row163_col3, #T_cd43c_row163_col4, #T_cd43c_row164_col3, #T_cd43c_row164_col4, #T_cd43c_row165_col3, #T_cd43c_row165_col4, #T_cd43c_row166_col3, #T_cd43c_row166_col4, #T_cd43c_row167_col3, #T_cd43c_row167_col4, #T_cd43c_row168_col3, #T_cd43c_row168_col4, #T_cd43c_row169_col3, #T_cd43c_row169_col4, #T_cd43c_row171_col3, #T_cd43c_row173_col3, #T_cd43c_row173_col4, #T_cd43c_row174_col3, #T_cd43c_row176_col3, #T_cd43c_row176_col4, #T_cd43c_row177_col3, #T_cd43c_row178_col3, #T_cd43c_row178_col4, #T_cd43c_row179_col3, #T_cd43c_row179_col4, #T_cd43c_row181_col3, #T_cd43c_row184_col3, #T_cd43c_row187_col3, #T_cd43c_row191_col3, #T_cd43c_row191_col4, #T_cd43c_row192_col3, #T_cd43c_row193_col3, #T_cd43c_row194_col3, #T_cd43c_row194_col4, #T_cd43c_row195_col3, #T_cd43c_row195_col4, #T_cd43c_row196_col3, #T_cd43c_row196_col4, #T_cd43c_row201_col3, #T_cd43c_row202_col3, #T_cd43c_row202_col4, #T_cd43c_row205_col3, #T_cd43c_row211_col3, #T_cd43c_row211_col4, #T_cd43c_row212_col3, #T_cd43c_row212_col4, #T_cd43c_row213_col3, #T_cd43c_row213_col4, #T_cd43c_row220_col3, #T_cd43c_row220_col4, #T_cd43c_row221_col3, #T_cd43c_row221_col4, #T_cd43c_row222_col3, #T_cd43c_row222_col4, #T_cd43c_row223_col3, #T_cd43c_row223_col4, #T_cd43c_row224_col3, #T_cd43c_row224_col4, #T_cd43c_row225_col3, #T_cd43c_row225_col4, #T_cd43c_row226_col3, #T_cd43c_row226_col4, #T_cd43c_row228_col3, #T_cd43c_row228_col4, #T_cd43c_row229_col3, #T_cd43c_row229_col4, #T_cd43c_row230_col3, #T_cd43c_row230_col4, #T_cd43c_row231_col3, #T_cd43c_row231_col4, #T_cd43c_row232_col3, #T_cd43c_row232_col4, #T_cd43c_row233_col3, #T_cd43c_row233_col4, #T_cd43c_row234_col3, #T_cd43c_row234_col4, #T_cd43c_row236_col3, #T_cd43c_row236_col4, #T_cd43c_row237_col3, #T_cd43c_row237_col4, #T_cd43c_row238_col3 ...
#   color: red;
# }
# </style>
# <table id="T_cd43c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd43c_level0_col0" class="col_heading level0 col0" >Day</th>
#       <th id="T_cd43c_level0_col1" class="col_heading level0 col1" >Depth</th>
#       <th id="T_cd43c_level0_col2" class="col_heading level0 col2" >Compare</th>
#       <th id="T_cd43c_level0_col3" class="col_heading level0 col3" >Welch p</th>
#       <th id="T_cd43c_level0_col4" class="col_heading level0 col4" >MWU p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd43c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd43c_row0_col0" class="data row0 col0" >Day 1</td>
#       <td id="T_cd43c_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cd43c_row0_col2" class="data row0 col2" >Control vs Root Mulched</td>
#       <td id="T_cd43c_row0_col3" class="data row0 col3" >0.4881</td>
#       <td id="T_cd43c_row0_col4" class="data row0 col4" >0.5412</td>
#     </tr>
#     <tr>
#       <th id="T_cd43c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd43c_row1_col0" class="data row1 col0" >Day 1</td>
#       <td id="T_cd43c_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_cd43c_row1_col2" class="data row1 col2" >Control vs Root Mixed</td>
#       <td id="T_cd43c_row1_col3" class="data row1 col3" >0.6737</td>
#       <td id="T_cd43c_row1_col4" class="data row1 col4" >0.8744</td>
#     </tr>
#     <tr>
#       <th id="T_cd43c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd43c_row2_col0" class="data row2 col0" >Day 1</td>
#       <td id="T_cd43c_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_cd43c_row2_col2" class="data row2 col2" >Control vs Leaf Mulched</td>
#       <td id="T_cd43c_row2_col3" class="data row2 col3" >0.2382</td>
#       <td id="T_cd43c_row2_col4" class="data row2 col4" >0.2849</td>
#     </tr>
#     <tr>
#       <th id="T_cd43c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd43c_row3_col0" class="data row3 col0" >Day 1</td>
#       <td id="T_cd43c_row3_col1" class="data
# C:\Users\Kenneth\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# === Depth Effect Across Time ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:331: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_668bb_row0_col3, #T_668bb_row0_col4, #T_668bb_row1_col3, #T_668bb_row1_col4, #T_668bb_row3_col3, #T_668bb_row3_col4, #T_668bb_row4_col3, #T_668bb_row4_col4, #T_668bb_row6_col3, #T_668bb_row6_col4, #T_668bb_row7_col3, #T_668bb_row7_col4, #T_668bb_row9_col3, #T_668bb_row9_col4, #T_668bb_row10_col3, #T_668bb_row10_col4, #T_668bb_row12_col3, #T_668bb_row12_col4, #T_668bb_row15_col3, #T_668bb_row15_col4, #T_668bb_row16_col3, #T_668bb_row16_col4, #T_668bb_row18_col3, #T_668bb_row18_col4, #T_668bb_row19_col3, #T_668bb_row19_col4, #T_668bb_row21_col3, #T_668bb_row21_col4, #T_668bb_row24_col3, #T_668bb_row24_col4, #T_668bb_row27_col3, #T_668bb_row27_col4, #T_668bb_row28_col3, #T_668bb_row28_col4, #T_668bb_row30_col3, #T_668bb_row30_col4, #T_668bb_row31_col3, #T_668bb_row32_col3, #T_668bb_row32_col4, #T_668bb_row33_col3, #T_668bb_row33_col4, #T_668bb_row34_col3, #T_668bb_row34_col4, #T_668bb_row35_col3, #T_668bb_row35_col4, #T_668bb_row36_col3, #T_668bb_row36_col4, #T_668bb_row37_col3, #T_668bb_row37_col4, #T_668bb_row38_col3, #T_668bb_row38_col4, #T_668bb_row39_col3, #T_668bb_row39_col4, #T_668bb_row40_col3, #T_668bb_row40_col4, #T_668bb_row41_col3, #T_668bb_row41_col4, #T_668bb_row42_col3, #T_668bb_row42_col4, #T_668bb_row43_col3, #T_668bb_row43_col4, #T_668bb_row45_col3, #T_668bb_row45_col4, #T_668bb_row46_col3, #T_668bb_row46_col4, #T_668bb_row47_col3, #T_668bb_row47_col4, #T_668bb_row48_col3, #T_668bb_row48_col4, #T_668bb_row50_col3, #T_668bb_row50_col4, #T_668bb_row51_col3, #T_668bb_row51_col4, #T_668bb_row53_col3, #T_668bb_row53_col4, #T_668bb_row54_col3, #T_668bb_row54_col4, #T_668bb_row56_col3, #T_668bb_row56_col4, #T_668bb_row57_col3, #T_668bb_row57_col4, #T_668bb_row59_col3, #T_668bb_row59_col4, #T_668bb_row60_col3, #T_668bb_row60_col4, #T_668bb_row63_col3, #T_668bb_row63_col4, #T_668bb_row64_col3, #T_668bb_row64_col4, #T_668bb_row66_col3, #T_668bb_row66_col4, #T_668bb_row67_col3, #T_668bb_row67_col4, #T_668bb_row68_col3, #T_668bb_row68_col4, #T_668bb_row69_col3, #T_668bb_row69_col4, #T_668bb_row70_col3, #T_668bb_row70_col4, #T_668bb_row71_col3, #T_668bb_row71_col4, #T_668bb_row72_col3, #T_668bb_row72_col4, #T_668bb_row73_col3, #T_668bb_row73_col4, #T_668bb_row75_col3, #T_668bb_row75_col4, #T_668bb_row76_col3, #T_668bb_row76_col4, #T_668bb_row77_col3, #T_668bb_row77_col4, #T_668bb_row78_col3, #T_668bb_row78_col4, #T_668bb_row79_col3, #T_668bb_row79_col4, #T_668bb_row80_col3, #T_668bb_row80_col4, #T_668bb_row81_col3, #T_668bb_row81_col4, #T_668bb_row82_col3, #T_668bb_row83_col3, #T_668bb_row83_col4, #T_668bb_row90_col3, #T_668bb_row90_col4, #T_668bb_row91_col3, #T_668bb_row91_col4, #T_668bb_row93_col3, #T_668bb_row94_col3, #T_668bb_row99_col3, #T_668bb_row99_col4, #T_668bb_row100_col3, #T_668bb_row100_col4, #T_668bb_row101_col3, #T_668bb_row101_col4, #T_668bb_row102_col3, #T_668bb_row102_col4, #T_668bb_row103_col3, #T_668bb_row103_col4, #T_668bb_row104_col3, #T_668bb_row104_col4, #T_668bb_row105_col3, #T_668bb_row105_col4, #T_668bb_row106_col3, #T_668bb_row106_col4, #T_668bb_row107_col3, #T_668bb_row107_col4, #T_668bb_row108_col3, #T_668bb_row108_col4, #T_668bb_row109_col3, #T_668bb_row109_col4, #T_668bb_row110_col3, #T_668bb_row110_col4, #T_668bb_row111_col3, #T_668bb_row111_col4, #T_668bb_row112_col3, #T_668bb_row112_col4, #T_668bb_row113_col3, #T_668bb_row113_col4, #T_668bb_row114_col3, #T_668bb_row114_col4, #T_668bb_row115_col3, #T_668bb_row115_col4, #T_668bb_row116_col3, #T_668bb_row116_col4, #T_668bb_row117_col3, #T_668bb_row117_col4, #T_668bb_row118_col3, #T_668bb_row118_col4, #T_668bb_row120_col3, #T_668bb_row120_col4, #T_668bb_row122_col3, #T_668bb_row122_col4, #T_668bb_row123_col3, #T_668bb_row123_col4, #T_668bb_row124_col3, #T_668bb_row130_col3, #T_668bb_row132_col3, #T_668bb_row132_col4, #T_668bb_row133_col3, #T_668bb_row133_col4, #T_668bb_row134_col3, #T_668bb_row134_col4, #T_668bb_row135_col3, #T_668bb_row135_col4, #T_668bb_row136_col3, #T_668bb_row136_col4, #T_668bb_row137_col3, #T_668bb_row137_col4, #T_668bb ...
#   color: red;
# }
# </style>
# <table id="T_668bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_668bb_level0_col0" class="col_heading level0 col0" >Treatment</th>
#       <th id="T_668bb_level0_col1" class="col_heading level0 col1" >Depth</th>
#       <th id="T_668bb_level0_col2" class="col_heading level0 col2" >Compare</th>
#       <th id="T_668bb_level0_col3" class="col_heading level0 col3" >Welch p</th>
#       <th id="T_668bb_level0_col4" class="col_heading level0 col4" >MWU p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_668bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_668bb_row0_col0" class="data row0 col0" >Control</td>
#       <td id="T_668bb_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_668bb_row0_col2" class="data row0 col2" >Day 1 vs Day 16</td>
#       <td id="T_668bb_row0_col3" class="data row0 col3" >0.0167</td>
#       <td id="T_668bb_row0_col4" class="data row0 col4" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_668bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_668bb_row1_col0" class="data row1 col0" >Control</td>
#       <td id="T_668bb_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_668bb_row1_col2" class="data row1 col2" >Day 1 vs Day 64</td>
#       <td id="T_668bb_row1_col3" class="data row1 col3" >0.0193</td>
#       <td id="T_668bb_row1_col4" class="data row1 col4" >0.0485</td>
#     </tr>
#     <tr>
#       <th id="T_668bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_668bb_row2_col0" class="data row2 col0" >Control</td>
#       <td id="T_668bb_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_668bb_row2_col2" class="data row2 col2" >Day 16 vs Day 64</td>
#       <td id="T_668bb_row2_col3" class="data row2 col3" >0.2805</td>
#       <td id="T_668bb_row2_col4" class="data row2 col4" >0.2881</td>
#     </tr>
#     <tr>
#       <th id="T_668bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_668bb_row3_col0" class="data row3 col0" >Control</td>
#       <td id="T_668bb_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_668bb_row3_col2" class="data row3 col2" >Day 1 vs Day 16</td>
#       <td id="T_668bb_row3_col3" class="data row3 col3" >0.0004</td>
#       <td id="T_668bb_row3_col4" class="data row3 col4" >0.0247</td>
#     </tr>
#     <tr>
#       <th id="T_668bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_668bb_row4_col0" class="data row4 col0" >Control</td>
#       <td id="T_668bb_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_668bb_row4_col2" class="data row4 col2" >Day 1 vs Day 64</td>
#       <td id="T_668bb_row4_col3" class="data row4 col3" >0.0217</td>
#       <td id="T_668bb_row4_col4" class="data row4 col4" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_668bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_668bb_row5_col0" class="data row5 col0" >Control</td>
#       <td id="T_668bb_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_668bb_row5_col2" class="data row5 col2" >Day 16 vs Day 64</td>
#       <td id="T_668bb_row5_col3" class="data row5 col3" >0.7354</td>
#       <td id="T_668bb_row5_col4" class="data row5 col4" >0.64
# C:\Users\Kenneth\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# === Depth × Treatment × Time Interaction ===
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_32508\1546393313.py:407: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_significant, subset=["Welch p", "MWU p"])
# <style type="text/css">
# #T_900bc_row7_col3, #T_900bc_row8_col3, #T_900bc_row110_col3, #T_900bc_row110_col4, #T_900bc_row111_col3, #T_900bc_row111_col4, #T_900bc_row112_col3, #T_900bc_row112_col4, #T_900bc_row113_col3, #T_900bc_row113_col4, #T_900bc_row114_col3, #T_900bc_row114_col4, #T_900bc_row115_col3, #T_900bc_row115_col4, #T_900bc_row116_col3, #T_900bc_row116_col4, #T_900bc_row117_col3, #T_900bc_row117_col4, #T_900bc_row118_col3, #T_900bc_row118_col4, #T_900bc_row120_col3, #T_900bc_row120_col4, #T_900bc_row121_col3, #T_900bc_row121_col4, #T_900bc_row122_col3, #T_900bc_row122_col4, #T_900bc_row123_col3, #T_900bc_row123_col4, #T_900bc_row124_col3, #T_900bc_row124_col4, #T_900bc_row125_col3, #T_900bc_row125_col4, #T_900bc_row126_col3, #T_900bc_row126_col4, #T_900bc_row127_col3, #T_900bc_row127_col4, #T_900bc_row128_col3, #T_900bc_row128_col4, #T_900bc_row130_col3, #T_900bc_row130_col4, #T_900bc_row131_col3, #T_900bc_row131_col4, #T_900bc_row132_col3, #T_900bc_row132_col4, #T_900bc_row133_col3, #T_900bc_row133_col4, #T_900bc_row134_col3, #T_900bc_row134_col4, #T_900bc_row135_col3, #T_900bc_row135_col4, #T_900bc_row136_col3, #T_900bc_row136_col4, #T_900bc_row137_col3, #T_900bc_row137_col4, #T_900bc_row138_col3, #T_900bc_row138_col4, #T_900bc_row140_col3, #T_900bc_row140_col4, #T_900bc_row141_col3, #T_900bc_row141_col4, #T_900bc_row142_col3, #T_900bc_row142_col4, #T_900bc_row143_col3, #T_900bc_row143_col4, #T_900bc_row144_col3, #T_900bc_row144_col4, #T_900bc_row145_col3, #T_900bc_row145_col4, #T_900bc_row146_col3, #T_900bc_row146_col4, #T_900bc_row147_col3, #T_900bc_row147_col4, #T_900bc_row148_col3, #T_900bc_row148_col4, #T_900bc_row151_col3, #T_900bc_row151_col4, #T_900bc_row152_col3, #T_900bc_row152_col4, #T_900bc_row153_col3, #T_900bc_row153_col4, #T_900bc_row154_col3, #T_900bc_row154_col4, #T_900bc_row155_col3, #T_900bc_row155_col4, #T_900bc_row156_col3, #T_900bc_row156_col4, #T_900bc_row161_col3, #T_900bc_row161_col4, #T_900bc_row162_col3, #T_900bc_row162_col4, #T_900bc_row163_col3, #T_900bc_row163_col4, #T_900bc_row164_col3, #T_900bc_row164_col4, #T_900bc_row165_col3, #T_900bc_row165_col4, #T_900bc_row166_col3, #T_900bc_row166_col4, #T_900bc_row167_col3, #T_900bc_row167_col4, #T_900bc_row168_col3, #T_900bc_row168_col4, #T_900bc_row171_col3, #T_900bc_row174_col3, #T_900bc_row177_col3, #T_900bc_row178_col3, #T_900bc_row181_col3, #T_900bc_row184_col3, #T_900bc_row187_col3, #T_900bc_row188_col3, #T_900bc_row191_col3, #T_900bc_row191_col4, #T_900bc_row192_col3, #T_900bc_row193_col3, #T_900bc_row194_col3, #T_900bc_row194_col4, #T_900bc_row195_col3, #T_900bc_row195_col4, #T_900bc_row196_col3, #T_900bc_row196_col4, #T_900bc_row201_col3, #T_900bc_row202_col3, #T_900bc_row202_col4, #T_900bc_row203_col3, #T_900bc_row203_col4, #T_900bc_row205_col3, #T_900bc_row206_col3, #T_900bc_row211_col3, #T_900bc_row211_col4, #T_900bc_row212_col3, #T_900bc_row212_col4, #T_900bc_row213_col3, #T_900bc_row213_col4, #T_900bc_row220_col3, #T_900bc_row220_col4, #T_900bc_row221_col3, #T_900bc_row221_col4, #T_900bc_row222_col3, #T_900bc_row222_col4, #T_900bc_row223_col3, #T_900bc_row223_col4, #T_900bc_row224_col3, #T_900bc_row224_col4, #T_900bc_row225_col3, #T_900bc_row225_col4, #T_900bc_row226_col3, #T_900bc_row226_col4, #T_900bc_row228_col3, #T_900bc_row228_col4, #T_900bc_row229_col3, #T_900bc_row229_col4, #T_900bc_row230_col3, #T_900bc_row230_col4, #T_900bc_row231_col3, #T_900bc_row231_col4, #T_900bc_row232_col3, #T_900bc_row232_col4, #T_900bc_row233_col3, #T_900bc_row233_col4, #T_900bc_row234_col3, #T_900bc_row234_col4, #T_900bc_row236_col3, #T_900bc_row236_col4, #T_900bc_row237_col3, #T_900bc_row237_col4, #T_900bc_row238_col3, #T_900bc_row238_col4, #T_900bc_row239_col3, #T_900bc_row239_col4, #T_900bc_row240_col3, #T_900bc_row240_col4, #T_900bc_row241_col3, #T_900bc_row241_col4, #T_900bc_row242_col3, #T_900bc_row242_col4, #T_900bc_row243_col3, #T_900bc_row243_col4, #T_900bc_row244_col3, #T_900bc_row244_col4, #T_900bc_row245_col3, #T_900bc_row245_col4, #T_900bc_row246_col3,  ...
#   color: red;
# }
# </style>
# <table id="T_900bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_900bc_level0_col0" class="col_heading level0 col0" >Day</th>
#       <th id="T_900bc_level0_col1" class="col_heading level0 col1" >Depth</th>
#       <th id="T_900bc_level0_col2" class="col_heading level0 col2" >Compare</th>
#       <th id="T_900bc_level0_col3" class="col_heading level0 col3" >Welch p</th>
#       <th id="T_900bc_level0_col4" class="col_heading level0 col4" >MWU p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_900bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_900bc_row0_col0" class="data row0 col0" >Day 1</td>
#       <td id="T_900bc_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_900bc_row0_col2" class="data row0 col2" >Control vs Root Mulched</td>
#       <td id="T_900bc_row0_col3" class="data row0 col3" >0.4881</td>
#       <td id="T_900bc_row0_col4" class="data row0 col4" >0.5412</td>
#     </tr>
#     <tr>
#       <th id="T_900bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_900bc_row1_col0" class="data row1 col0" >Day 1</td>
#       <td id="T_900bc_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_900bc_row1_col2" class="data row1 col2" >Control vs Root Mixed</td>
#       <td id="T_900bc_row1_col3" class="data row1 col3" >0.6737</td>
#       <td id="T_900bc_row1_col4" class="data row1 col4" >0.8744</td>
#     </tr>
#     <tr>
#       <th id="T_900bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_900bc_row2_col0" class="data row2 col0" >Day 1</td>
#       <td id="T_900bc_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_900bc_row2_col2" class="data row2 col2" >Control vs Leaf Mulched</td>
#       <td id="T_900bc_row2_col3" class="data row2 col3" >0.2382</td>
#       <td id="T_900bc_row2_col4" class="data row2 col4" >0.2849</td>
#     </tr>
#     <tr>
#       <th id="T_900bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_900bc_row3_col0" class="data row3 col0" >Day 1</td>
#       <td id="T_900bc_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_900bc_row3_col2" class="data row3 col2" >Control vs Leaf Mixed</td>
#       <td id="T_900bc_row3_col3" class="data row3 col3" >0.2382</td>
#       <td id="T_900bc_row3_col4" class="data row3 col4" >0.2849</td>
#     </tr>
#     <tr>
#       <th id="T_900bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90
